# %% [markdown]
# # Uitwerkingen

# %% [markdown]
# ## Opdracht 1

# %%
for (int i = 1; i <= 100; i++)
{
    Console.WriteLine(i);
}

# %% [markdown]
# ## Opdracht 2

# %%
// In plaats van i++ doen we i-- (i = i - 1) waardoor de loop naar beneden aftelt. En we beginnen dan bij 100 en stoppen bij 1.
for (int i = 100; i >= 1; i--)
{
    Console.WriteLine(i);
}

# %% [markdown]
# ## Opdracht 3

# %%
// Optie 1: Alle 100 mogelijkheden controleren of het een even getal is
for (int i = 0; i < 100; i++)
{
    // Controleer of het getal even is
    if (i % 2 == 0)
    {
        Console.WriteLine(i);
    }
}

// Optie 2: Met stappen van 2 door de for loop heen gaan
for (int i = 0; i < 100; i +=2)
{
    Console.WriteLine(i);
}

# %% [markdown]
# ## Opdracht 4

# %%
// Buitenste loop voor de rijen
for (int i = 0; i < 5; i++) 
{
    // Binnenste loop voor de kolommen
    for (int j = 0; j < 5; j++)
    {
        Console.Write("*");
    }
    // Ga naar de volgende regel
    Console.WriteLine();
}

# %% [markdown]
# ## Opdracht 5

# %%
 // Variabele om de som op te slaan
int som = 0;

for (int i = 0; i <= 100; i++)
{
    // Voeg elk getal toe aan de som
    som += i;
}

Console.WriteLine("De som van alle getallen tussen 0 en 100 is: " + som);

# %% [markdown]
# ## Opdracht 6

# %%
int getal = 10;
int faculteit = 1;

for (int i = 1; i <= getal; i++)
{
    // Vermenigvuldig de huidige waarde van faculteit met i
    faculteit *= i; 
}

Console.WriteLine("De faculteit van " + getal + " is: " + faculteit);

# %% [markdown]
# ## Opdracht 7

# %%
 // Initialieer en print de eerste twee getallen
int getal1 = 1;
int getal2 = 1;
Console.Write(getal1 + " " + getal2 + " ");

// Initialiseer variabelen die nodig zijn voor de berekening van de reeks
int volgendGetal;
int aantalCijfers = 40;

 // Start bij het derde getal, daarom i met 2 initialiseren (want getal 1 en getal 2 is al geprint). Als we dat niet doen zouden we meer dan 40 getallen prunten
for (int i = 2; i < aantalCijfers; i++)
{
    // bereken en print het volgende getal a.d.h.v. de twee huidige getallen
    volgendGetal = getal1 + getal2;
    Console.Write(volgendGetal + " ");

    // schuif de getallen door zodat de volgende berekening ook weer klopt
    getal1 = getal2;
    getal2 = volgendGetal;
}
