# %% [markdown]
# ## Opdracht 1

# %%
//List<int> solarProfits = new () {10, 4, 75, 9, 12, 90, 165};
List<int> solarProfits = new () {75, 75, 999, 75, 15, 2, -1, 75};// extra testlijst

for (int i = 0; i < solarProfits.Count; i++)
{
    if (solarProfits[i] == 75)
    {
        solarProfits[i] = 999;
    }
}

Console.WriteLine(string.Join(" ", solarProfits));
